# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import matplotlib.patches as mpatches

# %%
all_seasons = pd.read_csv('src/DATA/nba-players-data/all_seasons.csv')
alld = pd.read_csv('src/DATA/nba-players-stats/PlayersAndPlayersData.csv')


seasons_stats = pd.read_csv('src/DATA/nba-players-stats/seasons_stats.csv')
players = pd.read_csv('src/DATA/nba-players-stats/PlayersAndPlayersData.csv')
teams = pd.read_csv('src/DATA/teamState.csv')

# %%
tmab = []
for index, row in teams.iterrows():
    tmab.append(row['TeamAbr'])
    #print("<option value=\"{}\">{}</option>".format(row['TeamAbr'],row['Team']))

# %%
teams
# Out:
#              State                    Team TeamAbr StateAbr           City
# 0          Arizona            Phoenix Suns     PHX       AZ        Phoenix
# 1       California   Golden State Warriors     GSW       CA  San Fransisco
# 2       California    Los Angeles Clippers     LAC       CA    Los Angeles
# 3       California      Los Angeles Lakers     LAL       CA    Los Angeles
# 4       California        Sacramento Kings     SAC       CA     Sacramento
# 5         Colorado          Denver Nuggets     DEN       CO         Denver
# 6          Florida              Miami Heat     MIA       FL          Miami
# 7          Florida           Orlando Magic     ORL       FL        Orlando
# 8          Georgia           Atlanta Hawks     ATL       GA        Atlanta
# 9         Illinois           Chicago Bulls     CHI       IL        Chicago
# 10         Indiana          Indiana Pacers     IND       IN        Indiana
# 11       Louisiana    New Orleans Pelicans     NOP       LA    New Orleans
# 12   Massachusetts          Boston Celtics     BOS       MA         Boston
# 13        Michigan         Detroit Pistons     DET       MI        Detroit
# 14       Minnesota  Minnesota Timberwolves     MIN       MN      Minnesota
# 15        New York           Brooklyn Nets     BKN       NY       Brooklyn
# 16        New York         New York Knicks     NYK       NY       New York
# 17  North Carolina       Charlotte Hornets     CHA       NC      Charlotte
# 18            Ohio     Cleveland Cavaliers     CLE       OH      Cleveland
# 19        Oklahoma   Oklahoma City Thunder     OKC       OK       Oklahoma
# 20          Oregon  Portland Trail Blazers     POR       OR       Portland
# 21    Pennsylvania      Philadelphia 76ers     PHI       PA   Philadelphia
# 22       Tennessee       Memphis Grizzlies     MEM       TN        Memphis
# 23           Texas        Dallas Mavericks     DAL       TX         Dallas
# 24           Texas         Houston Rockets     HOU       TX        Houston
# 25           Texas       San Antonio Spurs     SAS       TX    San Antonio
# 26            Utah               Utah Jazz     UTA       UT           Utah
# 27       Wisconsin         Milwaukee Bucks     MIL       WI      Milwaukee
# 28   Washington DC      Washington Wizards     WAS       WA     Washington
# 29         Ontario         Toronto Raptors      ON      TOT        Toronto

# %%
for col in fileWar.columns: 
    #print("<input type=\"checkbox\" name = \"selectedStat\"  id=\"{}\"  value={}>\n<font size =5><label for=\"{}\">salut</label></font><br>".format(col, col, col))
# Out:
#   File "<ipython-input-129-dbdacf0eee51>", line 2
#     #print("<input type=\"checkbox\" name = \"selectedStat\"  id=\"{}\"  value={}>\n<font size =5><label for=\"{}\">salut</label></font><br>".format(col, col, col))
#                                                                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
playersa = []
for index, row in players.iterrows():
    playersa.append(row['Player'])

# %%
playersa
# Out:
# ['Curly Armstrong',
#  'Cliff Barker',
#  'Leo Barnhorst',
#  'Ed Bartels',
#  'Ralph Beard',
#  'Gene Berce',
#  'Charlie Black',
#  'Nelson Bobb',
#  'Jake Bornheimer',
#  'Vince Boryla',
#  'Don Boven',
#  'Harry Boykoff',
#  'Joe Bradley',
#  'Bob Brannum',
#  'Carl Braun',
#  'Frankie Brian',
#  'Price Brookfield',
#  'Bob Brown',
#  'Jim Browne',
#  'Walt Budko',
#  'Jack Burmaster',
#  'Tommy Byrnes',
#  'Bill Calhoun',
#  'Don Carlson',
#  'Bob Carpenter',
#  'Jake Carter',
#  'John Chaney',
#  'Leroy Chollet',
#  'Bill Closs',
#  'Paul Cloyd',
#  'Jack Coleman',
#  'Bobby Cook',
#  'Ray Corley',
#  'Jack Cotton',
#  'Dillard Crocker',
#  'Chink Crossin',
#  'Fran Curran',
#  'Jimmy Darden',
#  'Hook Dillon',
#  'Earl Dodd',
#  'Joe Dolhon',
#  'Bob Doll',
#  'Harry Donovan',
#  'Andy Duncan',
#  'Dike Eddleman',
#  'Gene Englund',
#  'Bob Evans',
#  'Johnny Ezersky',
#  'Bob Feerick',
#  'George Feigenbaum',
#  'Arnie Ferrin',
#  'Jerry Fleishman',
#  'Bill Gabor',
#  'Elmer Gainer',
#  'Vern Gardner',
#  'Frank Gates',
#  'Dee Gibson',
#  'Hoot Gibson',
#  'Chuck Gilmur',
#  'Normie Glick',
#  'Paul Gordon',
#  'Joe Graboski',
#  'Bud Grant',
#  'Don Grate',
#  'Alex Groza',
#  'Al Guokas',
#  'Robert Hahn',
#  'Chick Halbert',
#  'Bruce Hale',
#  'Dale Hamilton',
#  'John Hargis',
#  'Bob Harris',
#  'Bob Harrison',
#  'Billy Hassett',
#  'Marshall Hawkins',
#  'Bill Henry',
#  'Bill Herman',
#  'Kleggie Hermsen',
#  'Sonny Hertzberg',
#  'Paul Hoffman',
#  'Joe Holland',
#  'Gene James',
#  'Howie Janotta',
#  'Tony Jaros',
#  'Arnie Johnson',
#  'Ralph Johnson',
#  'Noble Jorgensen',
#  'George Kaftan',
#  'Leo Katkaveck',
#  'Jack Kerris',
#  'Bob Kinney',
#  'Walt Kirk',
#  'Leo Klier',
#  'Duane Klueh',
#  'Lee Knorek',
#  'Milo Komenich',
#  'Leo Kubiak',
#  'Frank Kudelka',
#  'Walt Lautenbach',
#  'Tony Lavelli',
#  'Ed Leede',
#  'Andrew Levane',
#  'Freddie Lewis',
#  'Freddie Lewis',
#  'Ron Livingstone',
#  'John Logan',
#  'Ray Lumpp',
#  'John Mahnken',
#  'John Mandic',
#  'Ariel Maughan',
#  'Matt Mazza',
#  'Mike McCarron',
#  'Bones McKinney',
#  'Mal McMullen',
#  'Dick Mehen',
#  'Ken Menke',
#  'Stan Miasek',
#  'Ed Mikan',
#  'Al Miksis',
#  'Murray Mitchell',
#  'Leo Mogus',
#  'Max Morris',
#  'Joe Mullaney',
#  'Jerry Nagel',
#  'Jack Nichols',
#  'Richie Niemiera',
#  'Paul Noel',
#  'Jim Nolan',
#  'Johnny Norlander',
#  'George Nostrand',
#  'Mike Novak',
#  "Dermie O'Connell",
#  "Andy O'Donnell",
#  "Dick O'Keefe",
#  'John Oldham',
#  'Gene Ollrich',
#  'Johnny Orr',
#  'Don Otten',
#  'Mac Otten',
#  'Red Owens',
#  'Easy Parham',
#  'Jack Parkinson',
#  'Charlie Parsley',
#  'Stan Patrick',
#  'Johnny Payak',
#  'Warren Perkins',
#  'Ed Peterson',
#  'Jack Phelan',
#  'John Pritchard',
#  'Les Pugh',
#  'Don Putman',
#  'George Ratkovicz',
#  'Don Ray',
#  'Chick Reiser',
#  'Tex Ritter',
#  'Bill Roberts',
#  'Red Rocha',
#  'Kenny Rollins',
#  'Bob Royer',
#  'Jerry Rullo',
#  'Ed Sadowski',
#  'Kenny Sailors',
#  'Pep Saul',
#  'Herm Schaefer',
#  'Marv Schatzman',
#  'Fred Schaus',
#  'Milt Schoon',
#  'Howie Schultz',
#  'Dick Schulz',
#  'Fred Scolari',
#  'Wayne See',
#  'Glen Selbo',
#  'Rollie Seltz',
#  'Jim Seminoff',
#  'George Senesky',
#  'Paul Seymour',
#  'Carl Shaeffer',
#  'Howie Shannon',
#  'Charley Shipp',
#  'Connie Simmons',
#  'Belus Smawley',
#  'Jack Smiley',
#  'Chips Sobek',
#  'Odie Spears',
#  'Art Spector',
#  'Ed Stanczak',
#  'Gene Stump',
#  'Mike Todorovich',
#  'Jack Toomay',
#  'Bob Tough',
#  'Blackie Towery',
#  'Dick Triptow',
#  'Gene Vance',
#  'Ernie Vandeweghe',
#  'Floyd Volker',
#  'Clint Wager',
#  'Danny Wagner',
#  'Brady Walker',
#  'Paul Walther',
#  'Murray Wier',
#  'D.C. Wilcutt',
#  'Bob Wood',
#  'Max Zaslofsky',
#  'Ed Beach',
#  'Leon Blevins',
#  'Ike Borsavage',
#  'Art Burris',
#  'Gerry Calabrese',
#  'Cal Christensen',
#  'Chuck Cooper',
#  'Hank DeZonie',
#  'Bob Donham',
#  'Ray Ellefson',
#  'Larry Foust',
#  'Ed Gayda',
#  'Joe Hutton',
#  'Bob Lavoy',
#  'Don Lofgran',
#  'Norm Mager',
#  'Joe McNamee',
#  'Chuck Mrazovich',
#  'Ken Murray',
#  "Tommy O'Keefe",
#  "Kevin O'Shea",
#  'Don Rehfeldt',
#  'Jim Riffey',
#  'Alan Sawyer',
#  'Herb Scherer',
#  'Dick Schnittker',
#  'Elmer Behnke',
#  'Stan Brown',
#  'Ed Dahler',
#  'Nate DeLong',
#  'Dick Dickey',
#  'Jake Fendley',
#  'Jerry Fowler',
#  'Lew Hitch',
#  'Mel Hutchins',
#  'Jack Kiley',
#  'George King',
#  'John McConathy',
#  'Dave Minor',
#  "Ralph O'Brien",
#  'Wally Osterkorn',
#  'Mel Payton',
#  'John Pilch',
#  'Ray Ragelis',
#  'Sam Ranzino',
#  'John Rennicke',
#  'Don Savage',
#  'Chuck Share',
#  'Zeke Sinicola',
#  'Whitey Skoog',
#  'Jim Slaughter',
#  'Bill Tosheff',
#  'Bob Wilson',
#  'Jim Baechtold',
#  'Jim Brasco',
#  'Dick Bunt',
#  'Gene Conley',
#  'Pete Darcey',
#  'Blaine Denning',
#  'Danny Finn',
#  'Dick Groat',
#  'Don Hanrahan',
#  'Don Henriksen',
#  'Jim Holstein',
#  'Bob Lochmueller',
#  'Mo Mahoney',
#  'Al Masino',
#  'Jack McCloskey',
#  'Bucky McConnell',
#  'George McLeod',
#  'Jack McMahon',
#  'Monk Meineke',
#  'Eddie Miller',
#  'Bill Mlkvy',
#  'Jim Mooney',
#  'Bob Naber',
#  "John O'Boyle",
#  "Mike O'Neill",
#  'Claude Overton',
#  'Ralph Polson',
#  'Bob Priddy',
#  'Moe Radovich',
#  'Sherwin Raiken',
#  'Gene Rhodes',
#  'Dick Surhoff',
#  'Mark Workman',
#  'Zeke Zawoluk',
#  'Don Ackerman',
#  'Don Asmonga',
#  'Ernie Barrett',
#  'Ernie Beck',
#  'Irv Bemoras',
#  'Bill Bolger',
#  'Walt Davis',
#  'Gene Dyker',
#  'Ed Earle',
#  'Ray Felix',
#  'Jim Fritsche',
#  'Jack George',
#  'Bato Govedarica',
#  'Norm Grekin',
#  'Rollen Hans',
#  'Billy Kenville',
#  'Dick Knostman',
#  'Jim Luisi',
#  'Jack Molinas',
#  'Jim Neal',
#  'Paul Nolen',
#  'Bob Peterson',
#  'James Phelan',
#  'Connie Rea',
#  'Frank Reddout',
#  'Al Roges',
#  'Ed Smith',
#  'Joe Smyth',
#  'Don Sunderlage',
#  'Norm Swanson',
#  'Hal Uplinger',
#  'Isaac Walthour',
#  'Don Anielak',
#  'Tom Brennan',
#  'Bob Carney',
#  'Fred Christ',
#  'Bert Cook',
#  'Larry Costello',
#  'George Dempsey',
#  'Fred Diute',
#  'Dick Farley',
#  'Chuck Grigsby',
#  'Herm Hedderick',
#  'Ed Kalafat',
#  'Mike Kearns',
#  'Red Kerr',
#  'Dan King',
#  'Bob Knight',
#  'Ronnie MacGilvray',
#  'Tom Marshall',
#  'Phil Martin',
#  'Ken McBride',
#  'Carl McNulty',
#  'Jackie Moore',
#  'Red Morrison',
#  'Boris Nachamkin',
#  'Togo Palazzi',
#  'Dick Rosenthal',
#  'Frank Selvy',
#  'Gene Shue',
#  'Art Spoelstra',
#  'Jim Tucker',
#  'Jack Turner',
#  'Jack Turner',
#  'Bobby Watson',
#  'Skippy Whitaker',
#  'Jesse Arnelle',
#  'Dick Atha',
#  'Don Bielke',
#  'Ed Conlin',
#  'Red Davis',
#  'Corky Devlin',
#  'Walter Dukes',
#  'Ron Feiereisel',
#  'Al Ferrari',
#  'Ed Fleming',
#  'Dick Garmaker',
#  'Chris Harris',
#  'Dick Hemric',
#  'Larry Hennessy',
#  'Johnny Horan',
#  'Jim Loscutoff',
#  'Chuck Mencel',
#  'Chuck Noble',
#  'Med Park',
#  'Richie Regan',
#  'Dick Ricketts',
#  'Bob Santini',
#  'Bob Schafer',
#  'Kenny Sears',
#  'Jack Stephens',
#  'Bob Williams',
#  'Forest Able',
#  'Bob Armstrong',
#  'John Barber',
#  'Gary Bergen',
#  'Al Bianchi',
#  'Bob Burrow',
#  'Si Green',
#  'Joe Holup',
#  'Bob Hopkins',
#  'Phil Jordon',
#  'Hal Lear',
#  'Johnny McCarthy',
#  'Willie Naulls',
#  'Jim Paxson',
#  'Jim Paxson',
#  'Dave Piontek',
#  'Jim Ray',
#  'Ron Shavlik',
#  'Ron Sobie',
#  'Norm Stewart',
#  'Bill Thieben',
#  'Lou Tsioropoulos',
#  'Doug Bolstorff',
#  'George Brown',
#  'Dick Duckett',
#  'Pat Dunn',
#  'Bill Ebben',
#  'Bo Erias',
#  'Larry Friend',
#  'McCoy Ingram',
#  'Jim Krebs',
#  'Brendan McCann',
#  'Worthy Patterson',
#  'Jerry Paulson',
#  'Ray Radziszewski',
#  'Lennie Rosenbluth',
#  'Woody Sauldsberry',
#  'Guy Sparrow',
#  'Charlie Tyra',
#  'Jim Walsh',
#  'Win Wilfong',
#  'Jerry Bird',
#  'Bucky Bockhorn',
#  'Pete Brennan',
#  'Barney Cable',
#  'Archie Dees',
#  'Connie Dierking',
#  'Boo Ellis',
#  'Mike Farmer',
#  'Dave Gambee',
#  'Steve Hamilton',
#  'Vern Hatton',
#  'Andy Johnson',
#  'Tommy Kearns',
#  'Shellie McMillon',
#  'Jim Palmer',
#  'Jack Parr',
#  'Hub Reed',
#  'Phil Rollins',
#  'Larry Staverman',
#  'Bennie Swain',
#  'Gary Alcorn',
#  'Bob Anderegg',
#  'Dick Barnett',
#  'Whitey Bell',
#  'Bob Ferry',
#  'Johnny Green',
#  'Gene Guarilia',
#  'Tom Hawkins',
#  'Maury King',
#  'Rudy LaRusso',
#  'Nick Mantis',
#  'Cal Ramsey',
#  'John Richter',
#  'Joe Ruklick',
#  'Bobby Smith',
#  'Wayne Stevens',
#  'Tony Windis',
#  'Al Attles',
#  'Bob Boozer',
#  'Dave Budd',
#  'Ralph Davis',
#  'Swede Halbrook',
#  'Darrall Imhoff',
#  'Ron Johnson',
#  'Howie Jolliff',
#  'Willie Jones',
#  'Pickles Kennedy',
#  'Fred LaCour',
#  'George Lee',
#  'Bob McNeill',
#  'Jackie Moreland',
#  'Don Ohl',
#  'Joe Roberts',
#  'Stacey Arceneaux',
#  'George Blaney',
#  'Joe Buckhalter',
#  'Cleveland Buckner',
#  'Ed Burton',
#  'Donnie Butcher',
#  'Al Butler',
#  'Howie Carl',
#  'Jimmy Darrow',
#  'Johnny Egan',
#  'Rich Eichhorst',
#  'Cleo Hill',
#  'Ron Horn',
#  'Doug Kistler',
#  'York Larese',
#  'Ted Luckenbill',
#  'Whitey Martin',
#  'Tom Meschery',
#  'Paul Neumann',
#  'Bevo Nordmann',
#  'Chuck Osborne',
#  'Gary Phillips',
#  'Frank Radovich',
#  'Ray Scott',
#  'Lee Shaffer',
#  'Bob Sims',
#  'Adrian Smith',
#  'Bill Smith',
#  'Sam Stith',
#  'Horace Walker',
#  'Bob Wiesenhahn',
#  'Wayne Yates',
#  'Dave Zeller',
#  'John Barnhill',
#  'Bill Bridges',
#  'Len Chappell',
#  'Johnny Cox',
#  'Terry Dischinger',
#  'Danny Doyle',
#  'Bob Duffy',
#  'Bob Duffy',
#  'Leroy Ellis',
#  'Dave Fedor',
#  'Jack Foley',
#  'Dave Gunther',
#  'Charlie Hardnett',
#  'Wayne Hightower',
#  'Paul Hogue',
#  'Kevin Loughery',
#  'Bill McGill',
#  'Porter Meriwether',
#  'Howie Montgomery',
#  'Mel Nowell',
#  'Bud Olsen',
#  'John Rudometkin',
#  'Jeff Slade',
#  'Tom Stith',
#  'Dan Swartz',
#  'Dan Tieman',
#  'Gene Tormohlen',
#  'Chico Vaughn',
#  'Ben Warley',
#  'Ralph Wells',
#  'Hubie White',
#  'Gene Wiley',
#  'Jay Arnette',
#  'Larry Comley',
#  'Mel Gibson',
#  'Jerry Greenspan',
#  'Reggie Harding',
#  'Jerry Harkness',
#  'Art Heyman',
#  'Gary Hill',
#  'Tom Hoover',
#  'Jim King',
#  'Don Kojis',
#  'Eddie Miles',
#  'Mel Peterson',
#  'Ken Rohloff',
#  'Larry Siegfried',
#  'Roger Strickland',
#  'Tom Thacker',
#  'Rod Thorn',
#  'Gerry Ward',
#  'John Windsor',
#  'Jim Barnes',
#  'Ron Bonham',
#  'Gary Bradds',
#  'Em Bryant',
#  'Joe Caldwell',
#  'Mel Counts',
#  'Steve Courtin',
#  'Jerry Grote',
#  'Happy Hairston',
#  'Walt Hazzard',
#  'Les Hunter',
#  'Luke Jackson',
#  'Luke Jackson',
#  'Larry Jones',
#  'Wali Jones',
#  'Howard Komives',
#  'Bud Koper',
#  'Barry Kramer',
#  'McCoy McLemore',
#  'Jeff Mullins',
#  'Cotton Nash',
#  'Paul Silas',
#  'John Tresvant',
#  'George Wilson',
#  'Jesse Branson',
#  'Bill Buntin',
#  'Barry Clemens',
#  'Keith Erickson',
#  'John Fairchild',
#  'Will Frazier',
#  'Fred Hetzel',
#  'Jon McGlocklin',
#  'Thales McReynolds',
#  'Ron Reed',
#  'Willie Somerset',
#  'Dave Stallworth',
#  'Joe Strawder',
#  'Bob Warlick',
#  'Jim Washington',
#  'Ron Watts',
#  'Bob Weiss',
#  'Henry Akin',
#  'Johnny Austin',
#  'Jim Barnett',
#  'John Block',
#  'Nate Bowman',
#  'Jerry Chambers',
#  'Archie Clark',
#  'Freddie Crawford',
#  'Dave Deutsch',
#  'Joe Ellis',
#  'Hank Finkel',
#  'Matt Guokas',
#  'Matt Guokas',
#  'Bob Hogsett',
#  'Lou Hudson',
#  'Neil Johnson',
#  'Toby Kimball',
#  'Tommy Kron',
#  'Clyde Lee',
#  'Bob Love',
#  'Jack Marin',
#  'Bill Melchionni',
#  'Wayne Molis',
#  'Erwin Mueller',
#  'Dorie Murrey',
#  'Flynn Robinson',
#  'Cazzie Russell',
#  'Dave Schellhase',
#  'Dick Snyder',
#  'Jim Ware',
#  'Walt Wesley',
#  'Bud Acton',
#  'Cliff Anderson',
#  'Tyrone Britt',
#  'Jim Burns',
#  'Jim Caldwell',
#  'George Carter',
#  'Jim Davis',
#  'Bill Dinwiddie',
#  'Sonny Dove',
#  'Ron Filipek',
#  'Jim Fox',
#  'Mal Graham',
#  'Gary Gray',
#  'Dennis Hamilton',
#  'Clem Haskins',
#  'Al Jackson',
#  'Johnny Jones',
#  'Nick Jones',
#  'Dave Lattin',
#  'George Lehmann',
#  'Bobby Lewis',
#  'Paul Long',
#  'Plummer Lott',
#  'Ed Manning',
#  'Stan McKenzie',
#  'Jay Miller',
#  'George Patterson',
#  'Jim Reid',
#  'Bob Rule',
#  'Craig Spitzer',
#  'Al Tucker',
#  'Bill Turner',
#  'Jimmy Walker',
#  'Rick Weitzman',
#  'Roland West',
#  'John Wetzel',
#  'Ken Wilburn',
#  'Art Williams',
#  'Tom Workman',
#  'Zaid Abdul-Aziz',
#  'Rick Adelman',
#  'Bob Allen',
#  'Harry Barnes',
#  'Ed Biedenbach',
#  'Tom Boerwinkle',
#  'Jay Carty',
#  'Don Chaney',
#  'Dick Cunningham',
#  'Fred Foster',
#  'Pat Frink',
#  'Gary Gregor',
#  'Al Hairston',
#  'Shaler Halimon',
#  'Skip Harlicka',
#  'Art Harris',
#  'Bill Hewitt',
#  'Bill Hosket',
#  'Rich Johnson',
#  'Bob Kauffman',
#  'Joe Kennedy',
#  'Rod Knowles',
#  'Stu Lantz',
#  'Don May',
#  'Otto Moore',
#  'Dave Newmark',
#  'Rich Niemann',
#  'Barry Orms',
#  'Charlie Paulk',
#  'Loy Petersen',
#  'Bob Quick',
#  'Craig Raymond',
#  'Mike Riordan',
#  'Dale Schlueter',
#  'Doug Sims',
#  'Greg Smith',
#  'Greg Smith',
#  'John Trapp',
#  'Dwight Waller',
#  'Cliff Williams',
#  'Ron Williams',
#  'Sam Williams',
#  'Sam Williams',
#  'Lucius Allen',
#  'Wally Anderzunas',
#  'John Arthurs',
#  'Johnny Baum',
#  'Butch Beard',
#  'Fred Carter',
#  'Bob Dandridge',
#  'Mike Davis',
#  'Mike Davis',
#  'Dick Garrett',
#  'Herm Gilliam',
#  'Bob Greacen',
#  'Lamar Green',
#  'Brian Heaney',
#  'Steve Kuberski',
#  'Mike Lynn',
#  'Willie McCarter',
#  'Steve Mix',
#  "Grady O'Malley",
#  'Bud Ogden',
#  'Bob Portman',
#  'Luther Rackley',
#  'George Reynolds',
#  'Rick Roberson',
#  'Dave Scholz',
#  'Bingo Smith',
#  'Neal Walk',
#  'John Warren',
#  'Bernie Williams',
#  'Lee Winfield',
#  'Don Adams',
#  'Bob Arnzen',
#  'Dennis Awtrey',
#  'Moe Barr',
#  'Tom Black',
#  'Bob Christian',
#  'Jimmy Collins',
#  'Joe Cooke',
#  'Pete Cross',
#  'Terry Driscoll',
#  'Claude English',
#  'Greg Fillmore',
#  'Levi Fontaine',
#  'Jake Ford',
#  'Gary Freeman',
#  'Walt Gilmore',
#  'Gar Heard',
#  'Al Henry',
#  'A.W. Holt',
#  'Greg Howard',
#  'John Hummer',
#  'Greg Hyder',
#  'George Johnson',
#  'George Johnson',
#  'George Johnson',
#  'John Johnson',
#  'Earnie Killum',
#  'Ron Knight',
#  'Sam Lacey',
#  'Harvey Marlatt',
#  'Eddie Mast',
#  'Jim McMillian',
#  'Larry Mikan',
#  'Rex Morgan',
#  'Ralph Ogden',
#  'Curtis Perry',
#  'Geoff Petrie',
#  'Mike Price',
#  'Bob Riley',
#  'Paul Ruffner',
#  'Mike Silliman',
#  'Garfield Smith',
#  'Dave Sorenson',
#  'Dennis Stewart',
#  'Bill Stricker',
#  'Gary Suiter',
#  'Fred Taylor',
#  'Joe Thomas',
#  'Rudy Tomjanovich',
#  'John Vallely',
#  'Cornell Warner',
#  'Bobby Washington',
#  'Jeff Webb',
#  'Herb White',
#  'Milt Williams',
#  'Willie Williams',
#  'Marv Winkler',
#  'Gary Zeller',
#  'Bill Zopf',
#  'Odis Allison',
#  'Vic Bartolome',
#  'Fred Brown',
#  'Austin Carr',
#  'Sid Catlett',
#  'Phil Chenier',
#  'Jim Cleamons',
#  'Charlie Davis',
#  'Jackie Dinkins',
#  'Ken Durrett',
#  'Dick Gibbs',
#  'Clarence Glover',
#  'Jeff Halliburton',
#  'Fred Hilton',
#  'Jake Jones',
#  'Mo Layton',
#  'Stan Love',
#  'Charlie Lowery',
#  'Jim Marsh',
#  'Jim McDaniels',
#  'Gil McGregor',
#  'Kenny McIntosh',
#  'Cliff Meely',
#  'Dean Meminger',
#  'John Mengelt',
#  'Barry Nelson',
#  'Mike Newlin',
#  'Willie Norwood',
#  'Steve Patterson',
#  'Tom Payne',
#  'Howard Porter',
#  'Clifford Ray',
#  'Jackie Ridgle',
#  'Rich Rinaldi',
#  'Curtis Rowe',
#  'Charlie Scott',
#  'Elmore Smith',
#  'Randy Smith',
#  'William Smith',
#  'Larry Steele',
#  'George Trapp',
#  'Sidney Wicks',
#  'Nate Williams',
#  'Isaiah Wilson',
#  'Dave Wohl',
#  'Barry Yates',
#  'Charlie Yelverton',
#  'Henry Bibby',
#  'Freddie Boyd',
#  'Steve Bracey',
#  'John Brisker',
#  'Roger Brown',
#  'Roger Brown',
#  'Corky Calhoun',
#  'Bob Davis',
#  'Dwight Davis',
#  'Mickey Davis',
#  'Charles Dudley',
#  'Scott English',
#  'Chris Ford',
#  'Harold Fox',
#  'Rowland Garrett',
#  'John Gianelli',
#  'Travis Grant',
#  'Luther Green',
#  'Charles Johnson',
#  'Ollie Johnson',
#  'Manny Leaks',
#  'Russ Lee',
#  'LaRue Martin',
#  'Paul McCracken',
#  'Eric McWilliams',
#  'Mark Minor',
#  'Bob Nash',
#  'Lloyd Neal',
#  'Tom Patterson',
#  'Kevin Porter',
#  'Jim Price',
#  'Mike Ratliff',
#  'Tom Riker',
#  'Ron Riley',
#  'Frank Russell',
#  'Frank Schade',
#  'Sam Sibert',
#  'Bud Stallworth',
#  'Paul Stovall',
#  'Chuck Terry',
#  'Justus Thigpen',
#  'John Tschogl',
#  'Paul Westphal',
#  'Harthorne Wingo',
#  'Joby Wright',
#  'Mike Bantom',
#  'Ron Behagen',
#  'Dennis Bell',
#  'Jim Brewer',
#  'Allan Bristow',
#  'John Brown',
#  'Larry Cannon',
#  'Bill Chamberlain',
#  'Ken Charles',
#  'E.C. Coleman',
#  'Doug Collins',
#  "Mike D'Antoni",
#  'Mel Davis',
#  'Derrek Dickey',
#  'Ernie DiGregorio',
#  'Steve Downing',
#  'Rod Freeman',
#  'Bernie Fryer',
#  'Jim Garvin',
#  'Phil Hankinson',
#  'Nate Hawthorne',
#  'Tom Ingelsby',
#  'Dwight Jones',
#  'Ben Kelso',
#  'Tom Kozelko',
#  'Kevin Kunnert',
#  'Mike Macaluso',
#  'Ted Manakas',
#  'Vester Marshall',
#  'Allie McGuire',
#  'Larry McNeill',
#  'Gary Melchionni',
#  'Louie Nelson',
#  'Jim Owens',
#  'Ed Ratleff',
#  'Joe Reaves',
#  'Mark Sibley',
#  'Bob Verga',
#  'Kermit Washington',
#  'Slick Watts',
#  'Nick Weatherspoon',
#  'Luke Witte',
#  'Dan Anderson',
#  'Dan Anderson',
#  'Jim Ard',
#  'Gus Bailey',
#  'Leon Benbow',
#  'Ken Boyd',
#  'Gary Brokaw',
#  'Tom Burleson',
#  'Harvey Catchings',
#  'Jim Chones',
#  'Ben Clyde',
#  'Jesse Dark',
#  'Rod Derline',
#  'John Drew',
#  'Dennis DuVal',
#  'Al Eberhard',
#  'Leonard Gray',
#  'Bernie Harris',
#  'Steve Hawes',
#  'Tom Henderson',
#  'Greg Jackson',
#  'Wardell Jackson',
#  'Aaron James',
#  'Mickey Johnson',
#  'Jimmy Jones',
#  'Frank Kendrick',
#  'Len Kosmalski',
#  'Bill Ligon',
#  'Phil Lumpkin',
#  'Glenn McDonald',
#  'Eric Money',
#  'Connie Norman',
#  'Kevin Restani',
#  'Truck Robinson',
#  'Campy Russell',
#  'Fred Saunders',
#  'Tal Skinner',
#  'Don Smith',
#  'Don Smith',
#  'Phil Smith',
#  'Mike Sojourner',
#  'Kevin Stacom',
#  'George Thompson',
#  'Dean Tolson',
#  'Foots Walker',
#  'Perry Warbington',
#  'Stan Washington',
#  'Scott Wedman',
#  'Owen Wells',
#  'Earl Williams',
#  'Bobby Wilson',
#  'Bobby Wilson',
#  'Brian Winters',
#  'Alvan Adams',
#  'Jerome Anderson',
#  'Jerry Baskerville',
#  'Bob Bigelow',
#  'Tom Boswell',
#  'Junior Bridgeman',
#  'Joe Bryant',
#  'Al Carlson',
#  'Jim Creighton',
#  ...]

# %%
for i in temp:
    i.to_csv("draftStates/{}.csv".format(i.iloc[0]["Player"].replace(" ", "_")))

# %%
ss = seasons_stats.groupby("Player").max()

# %%
# Out:
#                     Unnamed: 0    Year    Pos   Age   Tm     G    GS      MP  \
# Player
# A.C. Green               15148  2001.0     SF  37.0  TOT  83.0  82.0  2902.0
# A.J. Bramlett            14526  2000.0      C  23.0  CLE   8.0   0.0    61.0
# A.J. English             10583  1992.0     SG  24.0  WSB  81.0  12.0  1665.0
# A.J. Guyton              16172  2003.0     PG  24.0  GSW  45.0   8.0   630.0
# A.J. Hammons             24304  2017.0      C  24.0  DAL  22.0   0.0   163.0
# A.J. Price               23337  2015.0     SG  28.0  WAS  57.0  22.0  1278.0
# A.J. Wynder              10446  1991.0     PG  26.0  BOS   6.0   0.0    39.0
# A.W. Holt                 3175  1971.0     SF  24.0  CHI   6.0   NaN    14.0
# Aaron Brooks             24165  2017.0     PG  32.0  TOT  82.0  82.0  2919.0
# Aaron Gordon             24289  2017.0     SF  21.0  ORL  80.0  72.0  2298.0
# Aaron Gray               22488  2014.0      C  29.0  TOT  61.0  40.0   813.0
# Aaron Harrison           24315  2017.0     SG  22.0  CHO  21.0   0.0    93.0
# Aaron James               5536  1979.0     SF  26.0  NOJ  80.0   NaN  2118.0
# Aaron McKie              18534  2007.0  SG-SF  34.0  TOT  83.0  73.0  2394.0
# Aaron Miles              17990  2006.0     PG  22.0  GSW  19.0   0.0   118.0
# Aaron Swinson            12232  1995.0     SF  24.0  PHO   9.0   0.0    51.0
# Aaron Williams           19307  2008.0   PF-C  36.0  WAS  82.0  25.0  2336.0
# Abdul Jeelani             6237  1981.0     SF  26.0  POR  77.0   NaN  1286.0
# Acie Earl                12983  1997.0      C  26.0  TOT  74.0   8.0  1149.0
# Acie Law                 20860  2011.0     PG  26.0  TOT  56.0   6.0   865.0
# Adam Harrington          16182  2003.0     SG  22.0  TOT  19.0   0.0   111.0
# Adam Keefe               15214  2001.0     SF  30.0  UTA  82.0  75.0  2047.0
# Adam Morrison            20313  2010.0     SF  25.0  TOT  78.0  23.0  2326.0
# Adonal Foyle             19524  2009.0      C  33.0  TOT  82.0  72.0  1824.0
# Adonis Jordan            14199  1999.0     PG  28.0  MIL   6.0   0.0    79.0
# Adonis Thomas            22789  2014.0     SF  20.0  TOT   6.0   1.0    37.0
# Adreian Payne            24523  2017.0     PF  25.0  TOT  52.0  22.0   739.0
# Adrian Branch             9581  1990.0     SF  26.0  POR  67.0   4.0   811.0
# Adrian Caldwell          13490  1998.0     PF  31.0  TOT  51.0   1.0   569.0
# Adrian Dantley*          10094  1991.0     SF  34.0  UTA  81.0  81.0  3417.0
# ...                        ...     ...    ...   ...  ...   ...   ...     ...
# Worthy Patterson          1310  1958.0      G  26.0  STL   4.0   NaN    13.0
# Xavier Henry             23126  2015.0     SG  23.0  NOH  50.0  16.0   908.0
# Xavier McDaniel          13705  1998.0     SF  34.0  TOT  82.0  82.0  3031.0
# Xavier Munford           23908  2016.0     SG  23.0  MEM  14.0   0.0   244.0
# Xavier Silas             21560  2012.0     SG  24.0  PHI   2.0   0.0    39.0
# Yakhouba Diawara         20055  2010.0     SG  27.0  MIA  64.0  21.0  1177.0
# Yao Ming*                20903  2011.0      C  30.0  HOU  82.0  82.0  2692.0
# Yaroslav Korolev         18499  2007.0     SF  19.0  LAC  24.0   0.0   127.0
# Yi Jianlian              21406  2012.0     PF  24.0  WAS  66.0  52.0  1655.0
# Yinka Dare               13529  1998.0      C  25.0  NJN  58.0  23.0   626.0
# Yogi Ferrell             24261  2017.0     PG  23.0  TOT  46.0  29.0  1197.0
# York Larese               1751  1962.0     SG  23.0  TOT  59.0   NaN   703.0
# Yuta Tabuse              17572  2005.0     PG  24.0  PHO   4.0   0.0    17.0
# Yvon Joseph               8095  1986.0      C  28.0  NJN   1.0   0.0     5.0
# Zabian Dowdell           20675  2011.0     PG  26.0  PHO  24.0   0.0   292.0
# Zach LaVine              24408  2017.0     SG  21.0  MIN  82.0  47.0  2294.0
# Zach Randolph            24550  2017.0   PF-C  35.0  TOT  81.0  81.0  3067.0
# Zaid Abdul-Aziz           5009  1978.0   PF-C  31.0  TOT  80.0   NaN  2459.0
# Zan Tabak                15448  2001.0      C  30.0  TOT  67.0  34.0  1332.0
# Zarko Cabarkapa          17752  2006.0     PF  24.0  TOT  61.0   4.0   570.0
# Zarko Paspalj             9846  1990.0     SF  23.0  SAS  28.0   1.0   181.0
# Zaza Pachulia            24515  2017.0      C  32.0  ORL  79.0  78.0  2452.0
# Zeke Sinicola              888  1954.0      G  25.0  FTW   9.0   NaN    33.0
# Zeke Zawoluk              1020  1955.0     SF  24.0  PHW  71.0   NaN  1795.0
# Zeljko Rebraca           18079  2006.0      C  33.0  TOT  74.0  12.0  1179.0
# Zelmo Beaty*              4118  1975.0      C  35.0  STL  82.0   NaN  3072.0
# Zendon Hamilton          17871  2006.0     PF  30.0  TOT  54.0  15.0   848.0
# Zoran Dragic             23034  2015.0     SG  25.0  TOT  16.0   1.0    75.0
# Zoran Planinic           18061  2006.0     SG  23.0  NJN  56.0   8.0   596.0
# Zydrunas Ilgauskas       20802  2011.0      C  35.0  MIA  82.0  81.0  2615.0
#
#                      PER    TS%   ...      FT%    ORB    DRB     TRB    AST  \
# Player                            ...
# A.C. Green          17.8  0.603   ...    0.786  306.0  481.0   762.0  137.0
# A.J. Bramlett       -0.4  0.190   ...      NaN   12.0   10.0    22.0    0.0
# A.J. English        12.5  0.480   ...    0.841   74.0   94.0   168.0  177.0
# A.J. Guyton         11.8  0.495   ...    0.833   12.0   32.0    44.0   81.0
# A.J. Hammons         8.4  0.472   ...    0.450    8.0   28.0    36.0    4.0
# A.J. Price          17.1  0.542   ...    0.800   20.0   94.0   114.0  205.0
# A.J. Wynder          7.6  0.387   ...    0.750    1.0    2.0     3.0    8.0
# A.W. Holt           -1.8  0.215   ...    0.667    NaN    NaN     4.0    0.0
# Aaron Brooks        16.0  0.562   ...    0.940   54.0  161.0   215.0  434.0
# Aaron Gordon        17.0  0.541   ...    0.721  154.0  353.0   507.0  150.0
# Aaron Gray          18.4  0.644   ...    0.857   84.0  198.0   281.0   46.0
# Aaron Harrison       4.3  0.371   ...    0.500    4.0   11.0    15.0    3.0
# Aaron James         14.4  0.527   ...    0.781  163.0  258.0   421.0  112.0
# Aaron McKie         15.8  0.647   ...    0.870   86.0  289.0   350.0  377.0
# Aaron Miles          6.0  0.405   ...    1.000    0.0   14.0    14.0   24.0
# Aaron Swinson       11.7  0.594   ...    0.800    3.0    5.0     8.0    3.0
# Aaron Williams      19.1  0.606   ...    0.900  211.0  379.0   590.0   88.0
# Abdul Jeelani       18.7  0.563   ...    0.814  114.0  156.0   270.0   95.0
# Acie Earl           18.6  0.484   ...    0.719   85.0  162.0   247.0   27.0
# Acie Law            21.3  0.752   ...    0.857   12.0   52.0    63.0  113.0
# Adam Harrington     10.4  0.455   ...    1.000    1.0    7.0     8.0   12.0
# Adam Keefe          15.1  0.616   ...    0.810  179.0  279.0   455.0   89.0
# Adam Morrison        7.9  0.452   ...    0.762   54.0  176.0   230.0  163.0
# Adonal Foyle        21.0  0.623   ...    0.673  176.0  314.0   490.0   56.0
# Adonis Jordan       18.9  0.521   ...    0.500    3.0    3.0     6.0   19.0
# Adonis Thomas       10.1  0.700   ...    1.000    0.0    3.0     3.0    3.0
# Adreian Payne       14.4  0.505   ...    0.737   48.0  114.0   162.0   30.0
# Adrian Branch       18.8  0.576   ...    0.870   63.0   69.0   132.0   60.0
# Adrian Caldwell     10.4  0.556   ...    0.529   58.0  109.0   167.0   12.0
# Adrian Dantley*     24.6  0.661   ...    0.860  265.0  355.0   620.0  324.0
# ...                  ...    ...   ...      ...    ...    ...     ...    ...
# Worthy Patterson    11.0  0.394   ...    0.500    NaN    NaN     2.0    2.0
# Xavier Henry        12.3  0.511   ...    0.655   25.0   89.0   114.0   51.0
# Xavier McDaniel     18.7  0.539   ...    0.793  338.0  384.0   705.0  263.0
# Xavier Munford       9.9  0.481   ...    0.500    3.0   28.0    31.0   22.0
# Xavier Silas         0.1  0.337   ...    0.667    2.0    2.0     4.0    3.0
# Yakhouba Diawara     8.1  0.518   ...    0.710   27.0   83.0   110.0   55.0
# Yao Ming*           26.5  0.618   ...    0.938  208.0  557.0   761.0  137.0
# Yaroslav Korolev     8.0  0.392   ...    0.700    5.0    8.0    13.0    9.0
# Yi Jianlian         12.3  0.485   ...    0.841  115.0  259.0   372.0   60.0
# Yinka Dare           7.2  0.479   ...    0.613   56.0  125.0   181.0    3.0
# Yogi Ferrell        14.1  0.541   ...    0.877   20.0   91.0   111.0  172.0
# York Larese         13.1  0.501   ...    0.841    NaN    NaN    77.0   94.0
# Yuta Tabuse         15.6  0.451   ...    1.000    2.0    2.0     4.0    3.0
# Yvon Joseph         12.8  1.136   ...    1.000    0.0    0.0     0.0    0.0
# Zabian Dowdell      11.7  0.457   ...    0.941    5.0   15.0    20.0   51.0
# Zach LaVine         14.6  0.576   ...    0.842   27.0  201.0   228.0  276.0
# Zach Randolph       22.8  0.555   ...    0.821  330.0  620.0   950.0  200.0
# Zaid Abdul-Aziz     17.1  0.516   ...    0.804  259.0  664.0   923.0  166.0
# Zan Tabak           13.6  0.554   ...    0.690  117.0  203.0   320.0   62.0
# Zarko Cabarkapa     32.4  0.605   ...    1.000   37.0   74.0   111.0   40.0
# Zarko Paspalj        4.3  0.406   ...    0.818   15.0   15.0    30.0   10.0
# Zaza Pachulia       16.8  0.588   ...    0.846  264.0  469.0   718.0  178.0
# Zeke Sinicola       -1.7  0.295   ...    0.500    NaN    NaN     1.0    3.0
# Zeke Zawoluk        15.4  0.466   ...    0.809    NaN    NaN   330.0   99.0
# Zeljko Rebraca      16.2  0.625   ...    0.859   84.0  206.0   290.0   38.0
# Zelmo Beaty*        19.3  0.555   ...    0.800   93.0  234.0  1086.0  174.0
# Zendon Hamilton     18.2  0.624   ...    1.000  110.0  143.0   253.0   14.0
# Zoran Dragic         9.1  0.481   ...    0.667    5.0    3.0     8.0    5.0
# Zoran Planinic      12.5  0.534   ...    0.697   19.0   60.0    74.0   68.0
# Zydrunas Ilgauskas  21.9  0.576   ...    0.834  299.0  444.0   723.0  127.0
#
#                       STL    BLK    TOV     PF     PTS
# Player
# A.C. Green           94.0   80.0  120.0  229.0  1204.0
# A.J. Bramlett         1.0    0.0    3.0   13.0     8.0
# A.J. English         32.0   15.0  114.0  160.0   886.0
# A.J. Guyton          10.0    7.0   37.0   35.0   244.0
# A.J. Hammons          1.0   13.0   10.0   21.0    48.0
# A.J. Price           35.0    3.0   64.0   73.0   441.0
# A.J. Wynder           1.0    0.0    4.0    1.0    12.0
# A.W. Holt             NaN    NaN    NaN    1.0     4.0
# Aaron Brooks         69.0   15.0  232.0  199.0  1604.0
# Aaron Gordon         64.0   55.0   89.0  172.0  1019.0
# Aaron Gray           22.0   18.0   57.0  135.0   262.0
# Aaron Harrison        6.0    0.0    4.0   10.0    18.0
# Aaron James          41.0   22.0  130.0  254.0   973.0
# Aaron McKie         131.0   23.0  203.0  205.0   878.0
# Aaron Miles           4.0    1.0   11.0   13.0    16.0
# Aaron Swinson         1.0    0.0    5.0    8.0    24.0
# Aaron Williams       59.0  113.0  132.0  319.0   838.0
# Abdul Jeelani        44.0   40.0  117.0  155.0   737.0
# Acie Earl            24.0   53.0   72.0  178.0   410.0
# Acie Law             32.0    3.0   56.0   73.0   235.0
# Adam Harrington       2.0    1.0    2.0    8.0    30.0
# Adam Keefe           57.0   41.0  100.0  195.0   620.0
# Adam Morrison        28.0    6.0  130.0  179.0   917.0
# Adonal Foyle         44.0  205.0   80.0  218.0   440.0
# Adonis Jordan         3.0    1.0    6.0    6.0    15.0
# Adonis Thomas         0.0    0.0    1.0    6.0    14.0
# Adreian Payne        19.0   11.0   44.0   88.0   213.0
# Adrian Branch        45.0   11.0   64.0   99.0   498.0
# Adrian Caldwell      19.0   18.0   35.0   87.0   110.0
# Adrian Dantley*     118.0   24.0  299.0  252.0  2457.0
# ...                   ...    ...    ...    ...     ...
# Worthy Patterson      NaN    NaN    NaN    3.0     7.0
# Xavier Henry         44.0    8.0   57.0   79.0   432.0
# Xavier McDaniel     115.0   52.0  248.0  305.0  1890.0
# Xavier Munford       13.0    3.0   15.0   25.0    80.0
# Xavier Silas          0.0    0.0    3.0    5.0    11.0
# Yakhouba Diawara     30.0    7.0   37.0  132.0   284.0
# Yao Ming*            34.0  160.0  234.0  298.0  1514.0
# Yaroslav Korolev      3.0    0.0    6.0   11.0    27.0
# Yi Jianlian          37.0   56.0   90.0  170.0   623.0
# Yinka Dare            8.0   40.0   72.0  117.0   164.0
# Yogi Ferrell         42.0    9.0   70.0   90.0   462.0
# York Larese           NaN    NaN    NaN  104.0   302.0
# Yuta Tabuse           0.0    0.0    1.0    1.0     7.0
# Yvon Joseph           0.0    0.0    0.0    1.0     2.0
# Zabian Dowdell       20.0    2.0   29.0   30.0   121.0
# Zach LaVine          69.0   17.0  193.0  193.0  1150.0
# Zach Randolph        80.0   41.0  247.0  227.0  1681.0
# Zaid Abdul-Aziz      80.0  104.0   14.0  227.0   865.0
# Zan Tabak            24.0   38.0  101.0  204.0   514.0
# Zarko Cabarkapa      13.0   13.0   54.0   87.0   238.0
# Zarko Paspalj         3.0    7.0   21.0   37.0    72.0
# Zaza Pachulia        89.0   39.0  180.0  286.0   911.0
# Zeke Sinicola         NaN    NaN    NaN    8.0    11.0
# Zeke Zawoluk          NaN    NaN    NaN  220.0   592.0
# Zeljko Rebraca       28.0   73.0   84.0  192.0   513.0
# Zelmo Beaty*         45.0   29.0    NaN  344.0  1733.0
# Zendon Hamilton      21.0   18.0   60.0  104.0   324.0
# Zoran Dragic          2.0    0.0    5.0    6.0    28.0
# Zoran Planinic       25.0    4.0   43.0   91.0   217.0
# Zydrunas Ilgauskas   56.0  201.0  210.0  313.0  1390.0
#
# [3921 rows x 52 columns]

# %%
len(ss)
# Out:
# 3921

# %%
#temp = []
i=0
#for p in playersa:
    print(i/len(playersa))
    i=i+1
    tempa = (seasons_stats.loc[(seasons_stats['Player']  == p) ])
    temp.append(tempa.groupby("Tm").max())

# %%
players = []

# %%
playrs = ss.axes[0].tolist()

# %%
final = []
for p in playrs:
    temp =  seasons_stats.loc[seasons_stats["Player"]==p]
    temp.groupby("Tm").max().sort_values(by=['Year']).to_csv("src/DATA/draftStates/"+p.replace(" ", "_")+".csv")

# %%
final
# Out:
# ----------------------------------------------------
# NameError          Traceback (most recent call last)
# <ipython-input-12-faec0869773a> in <module>()
# ----> 1 final
#
# NameError: name 'final' is not defined
