# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import matplotlib.patches as mpatches

# %%
all_seasons = pd.read_csv('src/DATA/nba-players-data/all_seasons.csv')
alld = pd.read_csv('src/DATA/nba-players-stats/PlayersAndPlayersData.csv')


seasons_stats = pd.read_csv('src/DATA/nba-players-stats/seasons_stats.csv')
players = pd.read_csv('src/DATA/nba-players-stats/PlayersAndPlayersData.csv')
teams = pd.read_csv('src/DATA/teamState.csv')

# %%
tmab = []
for index, row in teams.iterrows():
    tmab.append(row['TeamAbr'])
    #print("<option value=\"{}\">{}</option>".format(row['TeamAbr'],row['Team']))

# %%
Shaquille O'Neal*
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Player, Pos, Age, Tm, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, blanl, OWS, DWS, WS, WS/48, blank2, OBPM, DBPM, BPM, VORP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 53 columns]

# %%
for col in fileWar.columns: 
    #print("<input type=\"checkbox\" name = \"selectedStat\"  id=\"{}\"  value={}>\n<font size =5><label for=\"{}\">salut</label></font><br>".format(col, col, col))
# Out:
#   File "<ipython-input-129-dbdacf0eee51>", line 2
#     #print("<input type=\"checkbox\" name = \"selectedStat\"  id=\"{}\"  value={}>\n<font size =5><label for=\"{}\">salut</label></font><br>".format(col, col, col))
#                                                                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
playersa = []
for index, row in players.iterrows():
    playersa.append(row['Player'])

# %%
aa = []
i=0
for d in df:
    i=i+1


    aa.append(d.groupby("Tm").max())
# Out:
# [0.000262[0.000524[0.000787[0.001049[0.001311[0.001573[0.001835[0.002098[0.002360[0.002622[0.002884[0.003146[0.003408[0.003671[0.003933[0.004195[0.004457[0.004719[0.004982[0.005244[0.005506[0.005768[0.006030[0.006293[0.006555[0.006817[0.007079[0.007341[0.007604[0.007866[0.008128[0.008390[0.008652[0.008915[0.009177[0.009439[0.009701[0.009963[0.010225[0.010488[0.010750[0.011012[0.011274[0.011536[0.011799[0.012061[0.012323[0.012585[0.012847[0.013110[0.013372[0.013634[0.013896[0.014158[0.014421[0.014683[0.014945[0.015207[0.015469[0.015732[0.015994[0.016256[0.016518[0.016780[0.017042[0.017305[0.017567[0.017829[0.018091[0.018353[0.018616[0.018878[0.019140[0.019402[0.019664[0.019927[0.020189[0.020451[0.020713[0.020975[0.021238[0.021500[0.021762[0.022024[0.022286[0.022549[0.022811[0.023073[0.023335[0.023597[0.023859[0.024122[0.024384[0.024646[0.024908[0.025170[0.025433[0.025695[0.025957[0.026219[0.026481[0.026744[0.027006[0.027268[0.027530[0.027792[0.028055[0.028317[0.028579[0.028841[0.02910
# ...

# %%
for i in temp:
    i.to_csv("draftStates/{}.csv".format(i.iloc[0]["Player"].replace(" ", "_")))

# %%
ss = seasons_stats.groupby("Player").max()

# %%
# Out:
#                     Unnamed: 0    Year    Pos   Age   Tm     G    GS      MP  \
# Player
# A.C. Green               15148  2001.0     SF  37.0  TOT  83.0  82.0  2902.0
# A.J. Bramlett            14526  2000.0      C  23.0  CLE   8.0   0.0    61.0
# A.J. English             10583  1992.0     SG  24.0  WSB  81.0  12.0  1665.0
# A.J. Guyton              16172  2003.0     PG  24.0  GSW  45.0   8.0   630.0
# A.J. Hammons             24304  2017.0      C  24.0  DAL  22.0   0.0   163.0
# A.J. Price               23337  2015.0     SG  28.0  WAS  57.0  22.0  1278.0
# A.J. Wynder              10446  1991.0     PG  26.0  BOS   6.0   0.0    39.0
# A.W. Holt                 3175  1971.0     SF  24.0  CHI   6.0   NaN    14.0
# Aaron Brooks             24165  2017.0     PG  32.0  TOT  82.0  82.0  2919.0
# Aaron Gordon             24289  2017.0     SF  21.0  ORL  80.0  72.0  2298.0
# Aaron Gray               22488  2014.0      C  29.0  TOT  61.0  40.0   813.0
# ...

# %%
len(ss)
# Out:
# 3921

# %%
#temp = []
i=0
#for p in playersa:
    print(i/len(playersa))
    i=i+1
    tempa = (seasons_stats.loc[(seasons_stats['Player']  == p) ])
    temp.append(tempa.groupby("Tm").max())

# %%
players = []

# %%
playrs = ss.axes[0].tolist()

# %%
final = []
for p in playrs:
    temp =  seasons_stats.loc[seasons_stats["Player"]==p]
    temp.groupby("Tm").max().sort_values(by=['Year']).to_csv("src/DATA/draftStates/"+p.replace(" ", "_")+".csv")

# %%
final
# Out:
# [     Unnamed: 0    Year           Player Pos   Age    G  GS  MP  PER    TS%  \
#  Tm
#  AND         175  1950.0  Murray Mitchell   C  26.0  2.0 NaN NaN  NaN  0.333
#
#      ...   FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
#  Tm  ...
#  AND ...   NaN  NaN  NaN  NaN  2.0  NaN  NaN  NaN  1.0  2.0
#
#  [1 rows x 52 columns]]
