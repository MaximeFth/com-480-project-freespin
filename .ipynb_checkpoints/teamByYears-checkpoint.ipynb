# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import matplotlib.patches as mpatches

# %%
all_seasons = pd.read_csv('src/DATA/nba-players-data/all_seasons.csv')

seasons_stats = pd.read_csv('src/DATA/nba-players-stats/seasons_stats.csv')
players = pd.read_csv('src/DATA/nba-players-stats/PlayersAndPlayersData.csv')
teams = pd.read_csv('src/DATA/teamState.csv')

# %%
teams
# Out:
#              State                    Team TeamAbr StateAbr
# 0          Arizona            Phoenix Suns     PHX       AZ
# 1       California   Golden State Warriors     GSW       CA
# 2       California    Los Angeles Clippers     LAC       CA
# 3       California      Los Angeles Lakers     LAL       CA
# 4       California        Sacramento Kings     SAC       CA
# 5         Colorado          Denver Nuggets     DEN       CO
# 6          Florida              Miami Heat     MIA       FL
# 7          Florida           Orlando Magic     ORL       FL
# 8          Georgia           Atlanta Hawks     ATL       GA
# 9         Illinois           Chicago Bulls     CHI       IL
# 10         Indiana          Indiana Pacers     IND       IN
# 11       Louisiana    New Orleans Pelicans     NOP       LA
# 12   Massachusetts          Boston Celtics     BOS       MA
# 13        Michigan         Detroit Pistons     DET       MI
# 14       Minnesota  Minnesota Timberwolves     MIN      NaN
# ...

# %%
tmab = []
for index, row in teams.iterrows():
    tmab.append(row['TeamAbr'])

# %%
all_seasons
# Out:
#        Unnamed: 0          player_name team_abbreviation   age  player_height  \
# 0               0        Dennis Rodman               CHI  36.0         198.12
# 1               1    Dwayne Schintzius               LAC  28.0         215.90
# 2               2         Earl Cureton               TOR  39.0         205.74
# 3               3          Ed O'Bannon               DAL  24.0         203.20
# 4               4          Ed Pinckney               MIA  34.0         205.74
# 5               5        Eddie Johnson               HOU  38.0         200.66
# 6               6          Eddie Jones               LAL  25.0         198.12
# 7               7       Elden Campbell               LAL  28.0         213.36
# 8               8    Eldridge Recasner               ATL  29.0         193.04
# 9               9         Elliot Perry               MIL  28.0         182.88
# 10             10        Elmer Bennett               DEN  27.0         182.88
# ...

# %%
players
# Out:
#       Unnamed: 0                 Player  height  weight    born  \
# 0              0        Curly Armstrong   180.0    77.0  1918.0
# 1              1           Cliff Barker   188.0    83.0  1921.0
# 2              2          Leo Barnhorst   193.0    86.0  1924.0
# 3              3             Ed Bartels   196.0    88.0  1925.0
# 4              4            Ralph Beard   178.0    79.0  1927.0
# 5              5             Gene Berce   180.0    79.0  1926.0
# 6              6          Charlie Black   196.0    90.0  1921.0
# 7              7            Nelson Bobb   183.0    77.0  1924.0
# 8              8        Jake Bornheimer   196.0    90.0  1927.0
# 9              9           Vince Boryla   196.0    95.0  1927.0
# 10            10              Don Boven   193.0    95.0  1925.0
# 11            11          Harry Boykoff   208.0   102.0  1922.0
# 12            12            Joe Bradley   190.0    79.0  1928.0
# 13            13            Bob Brannum   196.0    97.0  1925.0
# ...

# %%
seasons_stats
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# 5               5  1950.0         Ed Bartels    F  24.0  NYK   2.0   NaN
# 6               6  1950.0        Ralph Beard    G  22.0  INO  60.0   NaN
# 7               7  1950.0         Gene Berce  G-F  23.0  TRI   3.0   NaN
# 8               8  1950.0      Charlie Black  F-C  28.0  TOT  65.0   NaN
# 9               9  1950.0      Charlie Black  F-C  28.0  FTW  36.0   NaN
# 10             10  1950.0      Charlie Black  F-C  28.0  AND  29.0   NaN
# 11             11  1950.0        Nelson Bobb   PG  25.0  PHW  57.0   NaN
# ...

# %%
for team in tmab:
    for year in range(1950, 2018):
        file  = seasons_stats.loc[(seasons_stats['Year']  == year) & (seasons_stats['Tm'] == str(team)) ]
        file.to_csv('src/players_teams_seasons/{}{}.csv'.format(team, year))

# %%
file
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24137       24137  2017.0       Bradley Beal  SG  23.0  WAS  77.0  77.0
# 24153       24153  2017.0   Bojan Bogdanovic  SF  27.0  WAS  26.0   0.0
# 24173       24173  2017.0         Trey Burke  PG  24.0  WAS  57.0   0.0
# 24291       24291  2017.0      Marcin Gortat   C  32.0  WAS  82.0  82.0
# 24344       24344  2017.0       Danuel House  SG  23.0  WAS   1.0   0.0
# 24371       24371  2017.0   Brandon Jennings  PG  27.0  WAS  23.0   2.0
# 24434       24434  2017.0        Ian Mahinmi   C  30.0  WAS  31.0   0.0
# 24442       24442  2017.0  Sheldon McClellan  SG  24.0  WAS  30.0   3.0
# 24447       24447  2017.0   Chris McCullough  PF  21.0  WAS   2.0   0.0
# 24472       24472  2017.0    Markieff Morris  PF  27.0  WAS  76.0  76.0
# 24491       24491  2017.0   Andrew Nicholson  PF  27.0  WAS  28.0   0.0
# 24508       24508  2017.0      Daniel Ochefu   C  23.0  WAS  19.0   0.0
# ...
